# %%
class car:
    def __init__(self, speed = None , year = 2013):
        self.y1 = year
        self.sp1 = speed
        print(self.y1 , self.sp1)
        # can you tell me what change would happen if i change s and self
    def getSpeed(s):
        spd = 120
        print('max speed: ',s.sp1, "year: " ,s.y1)

# %%
BMW = car()
FORD = car()
BMW.speed = 150
# Out:
# 2013 None
# 2013 None

# %%
car.getSpeed(BMW)
car.getSpeed(FORD)
# Out:
# max speed:  None year:  2013
# max speed:  None year:  2013

# %%
class sedan(car):
    def acceleration(self):
        print('sudan 123')
    def opentrunk(self):
        print('trunk open')

class suv(car):
    def accelaration(self):
        print('suv 999')

# %%
s = sedan(120,1999)
s.getSpeed()
s.acceleration()
sedan.acceleration(s)
# Out:
# 1999 120
# max speed:  120 year:  1999
# sudan 123
# sudan 123

# %%
# multiple inheritence 
class ABC():
    abc = 10
    wa = 90

class pqr():
    abc = 15
    vb = 800

class xyz(ABC,pqr):
    xyz = 20

# %%
obj_pqr = pqr()
obj_pqr.abc
obj_abc = ABC()
obj_abc.abc
obj_xyz = xyz() # here the order of inheritance is followed : class abc was first so we got the variable from abc object 
obj_xyz.abc , obj_xyz.wa ,  obj_xyz.vb
# Out:
# (10, 90, 800)

# %%
# ENCAPSULATION
class car():
    dealer = 'SSS'
    def __init__(self, year, speed):
        self.year = year
        self.speed = speed

    def getspeed(self):
        print('select speed from tab1 where ')
        print('display info on view')
        print('get max speed', self.speed)


    def setspeed(s):
        print('ask iser to enter info regi page')
        s.speed = input('enter current speed')
        print('update speed set colname - s.speed where ')
        print('setting max speed to ', s.speed)

    punch = car(2020,120)

# %%
# checking inheritence of __init__ class
class Animal:
	def __init__(self):
		print("Animal constructor")
class Dog(Animal):
	def __init__(self):
		super().__init__()
		print("Dog constructor")

# %%
d = Dog()
# Out:
# Animal constructor
# Dog constructor
# [__main__.Dog, __main__.Animal, object]

# %%
class computer:
    shop_name = 'techies'

    def __init__(self):
        self.__maxprice = 900   # private variable
        self._b = 100           # protected (convention)
        self.model_name = 'dell'

    def sell(self):
        print("{} selling price : {}".format(self.model_name, self.__maxprice))

    def setMaxprice(self, price):
        self.__maxprice = price

# %%
c = computer()
computer.sell(c)
c.model_name
c.__maxprice # this will show error as python stores private variable with the class name like below
c._computer__maxprice # name mangling ( to restrict accidental access of the private variable)
# Out:
# 900

# %%
class employee:
    def setwork(self):
        self.work = 40
    def dispwork(self):
        print(self.work)
        return self.work
class Trainee(employee):
    def setwork(self):
        self.work = 45
    def dispwork(self):
        print(self.work)
        return self.work
    def reseting(self):
        super().setwork()

# %%
emp = employee()
emp.setwork()
emp.dispwork()
sahil = employee()
bhushan = Trainee()
sahil.setwork()
bhushan.setwork()
sahil.dispwork()
bhushan.dispwork()

list01 = [ sahil , bhushan]
for name in list01:
    print(name.dispwork())
# Out:
# 40
# 40
# 45
# 40
# 40
# 45
# 45

# %%
# see the website click on the website and check on the functionality and see how it relates to each other (UML diagram)
# what can be the classess ,
# what can be the methods ,
# what can be the attributes
# 
# 


def add(a, b):
	return a + b
def add(a, b, c):
	return a + b + c

print(add(10,5,4))
# true method overloading does not exist in python



# so this is what we do in pyton instead:
def add(*args):
	return sum(args)

print(add(10,5))
print(add(10,5,4))
# Out:
# 19
# 15
# 19

# %%
class Shape:
	def area(self):
		print('global area')
class Circle(Shape):
	def area(self):
		print("Circle area")
class Square(Shape):
	def area(self):
		print("Square area")
class Demo(Circle , Shape):
	pass
		
shapes = [Circle(), Square(),Shape(),Demo()]
for shape in shapes:
    shape.area()
# Out:
# Circle area
# Square area
# global area
# Circle area

# %%
class Cal:
    def add(self, a, b , c = 0):
        return a + b + c

obj = Cal()
print(obj.add(1, 2))
# Out:
# 3

# %%
class SahilBankAccount:
    '''
    this class stores all the accounts 
    '''
    sahil_accounts_dict = {}

    def __init__(self, account_number, name, initial_balance):
        self.account_number = account_number
        self.name = name
        self.__balance = initial_balance  

    def deposit(self, amount):
        if amount <= 0:
            print("Deposit amount must be positive.")
            return
        self.__balance += amount
        print(f"{amount} deposited successfully.")

    def withdraw(self, amount):
        if amount <= 0:
            print("Withdrawal amount must be positive.")
            return
        if amount > self.__balance:
            print("Insufficient balance.")
            return
        self.__balance -= amount
        print(f"{amount} withdrawn successfully.")

    def check_balance(self):
        print(f"Current Balance: {self.__balance}")
        
    
    def get_balance(self):  # Used internally for transfer
        return self.__balance

    def receive_transfer(self, amount):
        self.__balance += amount

    @classmethod
    def create_account(cls):
        try:
            acc_no = int(input("Enter Account Number: "))
            if acc_no in cls.sahil_accounts_dict:
                print("Account already exists.")
                return

            name = input("Enter Account Holder Name: ")
            balance = float(input("Enter Initial Balance: "))

            if balance < 0:
                print("Initial balance cannot be negative.")
                return

            account_obj = SahilBankAccount(acc_no, name, balance)
            cls.sahil_accounts_dict[acc_no] = account_obj
            print("Account created successfully.")

        except ValueError:
            print("Invalid input.")

    @classmethod
    def get_account(cls, acc_no):
        return cls.sahil_accounts_dict.get(acc_no)

    @classmethod
    def transfer_money(cls):
        try:
            from_acc = int(input("From Account Number: "))
            to_acc = int(input("To Account Number: "))
            amount = float(input("Enter Amount to Transfer: "))

            sender = cls.get_account(from_acc)
            receiver = cls.get_account(to_acc)

            if not sender or not receiver:
                print("One or both accounts do not exist.")
                return

            if amount <= 0:
                print("Transfer amount must be positive.")
                return

            if sender.get_balance() < amount:
                print("Insufficient balance in sender account.")
                return

            sender.withdraw(amount)
            receiver.receive_transfer(amount)

            print("Transfer successful.")

        except ValueError:
            print("Invalid input.")



def sahil_bank_menu():
    while True:
        print("\n===== Sahil Bank System =====")
        print("1. Create Account")
        print("2. Deposit")
        print("3. Withdraw")
        print("4. Check Balance")
        print("5. Transfer Money")
        print("6. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            SahilBankAccount.create_account()

        elif choice == "2":
            acc_no = int(input("Enter Account Number: "))
            account = SahilBankAccount.get_account(acc_no)
            if account:
                amount = float(input("Enter Deposit Amount: "))
                account.deposit(amount)
            else:
                print(" Account not found.")

        elif choice == "3":
            acc_no = int(input("Enter Account Number: "))
            account = SahilBankAccount.get_account(acc_no)
            if account:
                amount = float(input("Enter Withdrawal Amount: "))
                account.withdraw(amount)
            else:
                print(" Account not found.")

        elif choice == "4":
            acc_no = int(input("Enter Account Number: "))
            account = SahilBankAccount.get_account(acc_no)
            if account:
                account.check_balance()
            else:
                print(" Account not found.")

        elif choice == "5":
            SahilBankAccount.transfer_money()

        elif choice == "6":
            print("Thank you for using Sahil Bank.")
            break

        else:
            print(" Invalid choice.")


# Run Program
sahil_bank_menu()
# Out:
# ===== Sahil Bank System =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Transfer Money
# 6. Exit
#  Invalid choice.
#
# ===== Sahil Bank System =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Transfer Money
# 6. Exit
# Account created successfully.
#
# ===== Sahil Bank System =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Transfer Money
# 6. Exit
#  Invalid choice.
#
# ===== Sahil Bank System =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Transfer Money
# 6. Exit
#  Invalid choice.
#
# ===== Sahil Bank System =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Transfer Money
# 6. Exit
#  Invalid choice.
#
# ===== Sahil Bank System =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Transfer Money
# 6. Exit
#  Invalid choice.
#
# ===== Sahil Bank System =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# ...
